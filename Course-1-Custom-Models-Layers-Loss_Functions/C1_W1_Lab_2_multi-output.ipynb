# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 274.7511 - y1_output_loss: 134.0313 - y2_output_loss: 138.6274 - y1_output_root_mean_squared_error: 11.6162 - y2_output_root_mean_squared_error: 11.8243 - val_loss: 37.8834 - val_y1_output_loss: 17.6079 - val_y2_output_loss: 19.6846 - val_y1_output_root_mean_squared_error: 4.1950 - val_y2_output_root_mean_squared_error: 4.5039
# Epoch 2/500
# 614/614 [==============================] - 0s 154us/sample - loss: 29.9109 - y1_output_loss: 13.0085 - y2_output_loss: 17.6306 - y1_output_root_mean_squared_error: 3.5453 - y2_output_root_mean_squared_error: 4.1643 - val_loss: 51.9147 - val_y1_output_loss: 18.5689 - val_y2_output_loss: 32.9076 - val_y1_output_root_mean_squared_error: 4.3367 - val_y2_output_root_mean_squared_error: 5.7539
# Epoch 3/500
# 614/614 [==============================] - 0s 163us/sample - loss: 27.0869 - y1_output_loss: 10.5660 - y2_output_loss: 16.3878 - y1_output_root_mean_squared_error: 3.2580 - y2_output_root_mean_squared_error: 4.0586 - val_loss: 37.2060 - val_y1_output_loss: 13.4398 - val_y2_output_loss: 24.2516 - val_y1_output_root_mean_squared_error: 3.6092 - val_y2_output_root_mean_squared_error: 4.9173
# Epoch 4/500
# 614/614 [==============================] - 0s 152us/sample - loss: 22.6087 - y1_output_loss: 9.5737 - y2_output_loss: 12.9173 - y1_output_root_mean_squared_error: 3.0952 - y2_output_root_mean_squared_error: 3.6095 - val_loss: 32.8197 - val_y1_output_loss: 12.9401 - val_y2_output_loss: 19.9440 - val_y1_output_root_mean_squared_error: 3.5559 - val_y2_output_root_mean_squared_error: 4.4917
# Epoch 5/500
# 614/614 [==============================] - 0s 146us/sample - loss: 23.3137 - y1_output_loss: 9.4824 - y2_output_loss: 14.1796 - y1_output_root_mean_squared_error: 3.0533 - y2_output_root_mean_squared_error: 3.7404 - val_loss: 45.3431 - val_y1_output_loss: 13.1968 - val_y2_output_loss: 33.3456 - val_y1_output_root_mean_squared_error: 3.5974 - val_y2_output_root_mean_squared_error: 5.6923
# Epoch 6/500
# 614/614 [==============================] - 0s 145us/sample - loss: 27.5734 - y1_output_loss: 10.3743 - y2_output_loss: 17.3664 - y1_output_root_mean_squared_error: 3.1977 - y2_output_root_mean_squared_error: 4.1651 - val_loss: 49.6824 - val_y1_output_loss: 15.5735 - val_y2_output_loss: 34.5149 - val_y1_output_root_mean_squared_error: 3.8968 - val_y2_output_root_mean_squared_error: 5.8735
# Epoch 7/500
# 614/614 [==============================] - 0s 146us/sample - loss: 22.6276 - y1_output_loss: 8.8152 - y2_output_loss: 14.0201 - y1_output_root_mean_squared_error: 2.9681 - y2_output_root_mean_squared_error: 3.7172 - val_loss: 42.7788 - val_y1_output_loss: 11.8542 - val_y2_output_loss: 31.2206 - val_y1_output_root_mean_squared_error: 3.4432 - val_y2_output_root_mean_squared_error: 5.5609
# Epoch 8/500
# 614/614 [==============================] - 0s 140us/sample - loss: 22.3383 - y1_output_loss: 8.7799 - y2_output_loss: 13.4286 - y1_output_root_mean_squared_error: 2.9748 - y2_output_root_mean_squared_error: 3.6727 - val_loss: 26.7069 - val_y1_output_loss: 9.0720 - val_y2_output_loss: 17.5309 - val_y1_output_root_mean_squared_error: 2.9827 - val_y2_output_root_mean_squared_error: 4.2202
# Epoch 9/500
# 614/614 [==============================] - 0s 140us/sample - loss: 22.5898 - y1_output_loss: 8.5219 - y2_output_loss: 13.8836 - y1_output_root_mean_squared_error: 2.9299 - y2_output_root_mean_squared_error: 3.7424 - val_loss: 18.9636 - val_y1_output_loss: 7.4098 - val_y2_output_loss: 11.3840 - val_y1_output_root_mean_squared_error: 2.7137 - val_y2_output_root_mean_squared_error: 3.4058
# Epoch 10/500
# 614/614 [==============================] - 0s 143us/sample - loss: 24.0169 - y1_output_loss: 9.0563 - y2_output_loss: 15.2041 - y1_output_root_mean_squared_error: 2.9960 - y2_output_root_mean_squared_error: 3.8783 - val_loss: 64.3871 - val_y1_output_loss: 18.0047 - val_y2_output_loss: 48.7578 - val_y1_output_root_mean_squared_error: 4.1862 - val_y2_output_root_mean_squared_error: 6.8456
# Epoch 11/500
# 614/614 [==============================] - 0s 143us/sample - loss: 24.6886 - y1_output_loss: 8.7218 - y2_output_loss: 15.7432 - y1_output_root_mean_squared_error: 2.9656 - y2_output_root_mean_squared_error: 3.9867 - val_loss: 23.6206 - val_y1_output_loss: 9.0341 - val_y2_output_loss: 14.6245 - val_y1_output_root_mean_squared_error: 2.9704 - val_y2_output_root_mean_squared_error: 3.8467
# Epoch 12/500
# 614/614 [==============================] - 0s 144us/sample - loss: 20.4053 - y1_output_loss: 8.3066 - y2_output_loss: 12.0892 - y1_output_root_mean_squared_error: 2.8819 - y2_output_root_mean_squared_error: 3.4785 - val_loss: 31.1111 - val_y1_output_loss: 8.8429 - val_y2_output_loss: 22.4131 - val_y1_output_root_mean_squared_error: 2.9294 - val_y2_output_root_mean_squared_error: 4.7465
# Epoch 13/500
# 614/614 [==============================] - 0s 143us/sample - loss: 21.4005 - y1_output_loss: 8.1184 - y2_output_loss: 13.1247 - y1_output_root_mean_squared_error: 2.8618 - y2_output_root_mean_squared_error: 3.6346 - val_loss: 17.8911 - val_y1_output_loss: 7.2129 - val_y2_output_loss: 10.8435 - val_y1_output_root_mean_squared_error: 2.6626 - val_y2_output_root_mean_squared_error: 3.2866
# Epoch 14/500
# 614/614 [==============================] - 0s 150us/sample - loss: 19.6459 - y1_output_loss: 7.9977 - y2_output_loss: 12.2093 - y1_output_root_mean_squared_error: 2.8201 - y2_output_root_mean_squared_error: 3.4195 - val_loss: 28.8121 - val_y1_output_loss: 9.1509 - val_y2_output_loss: 19.8611 - val_y1_output_root_mean_squared_error: 3.0204 - val_y2_output_root_mean_squared_error: 4.4372
# Epoch 15/500
# 614/614 [==============================] - 0s 148us/sample - loss: 23.0717 - y1_output_loss: 8.8309 - y2_output_loss: 14.1746 - y1_output_root_mean_squared_error: 2.9784 - y2_output_root_mean_squared_error: 3.7684 - val_loss: 18.0468 - val_y1_output_loss: 7.5044 - val_y2_output_loss: 10.7291 - val_y1_output_root_mean_squared_error: 2.7049 - val_y2_output_root_mean_squared_error: 3.2757
# Epoch 16/500
# 614/614 [==============================] - 0s 144us/sample - loss: 22.5029 - y1_output_loss: 8.1518 - y2_output_loss: 14.2142 - y1_output_root_mean_squared_error: 2.8653 - y2_output_root_mean_squared_error: 3.7806 - val_loss: 18.6284 - val_y1_output_loss: 7.5327 - val_y2_output_loss: 10.9960 - val_y1_output_root_mean_squared_error: 2.7481 - val_y2_output_root_mean_squared_error: 3.3281
# Epoch 17/500
# 614/614 [==============================] - 0s 143us/sample - loss: 19.9434 - y1_output_loss: 7.5902 - y2_output_loss: 12.3990 - y1_output_root_mean_squared_error: 2.7474 - y2_output_root_mean_squared_error: 3.5207 - val_loss: 21.1793 - val_y1_output_loss: 8.1732 - val_y2_output_loss: 13.3983 - val_y1_output_root_mean_squared_error: 2.8306 - val_y2_output_root_mean_squared_error: 3.6287
# Epoch 18/500
# 614/614 [==============================] - 0s 140us/sample - loss: 16.0663 - y1_output_loss: 6.6726 - y2_output_loss: 9.3075 - y1_output_root_mean_squared_error: 2.5871 - y2_output_root_mean_squared_error: 3.0616 - val_loss: 25.4111 - val_y1_output_loss: 8.5198 - val_y2_output_loss: 17.0411 - val_y1_output_root_mean_squared_error: 2.8867 - val_y2_output_root_mean_squared_error: 4.1326
# Epoch 19/500
# 614/614 [==============================] - 0s 146us/sample - loss: 18.1296 - y1_output_loss: 7.0600 - y2_output_loss: 11.0869 - y1_output_root_mean_squared_error: 2.6463 - y2_output_root_mean_squared_error: 3.3356 - val_loss: 17.4438 - val_y1_output_loss: 5.8305 - val_y2_output_loss: 11.3798 - val_y1_output_root_mean_squared_error: 2.4224 - val_y2_output_root_mean_squared_error: 3.4023
# Epoch 20/500
# 614/614 [==============================] - 0s 145us/sample - loss: 17.0561 - y1_output_loss: 6.6953 - y2_output_loss: 10.6332 - y1_output_root_mean_squared_error: 2.5831 - y2_output_root_mean_squared_error: 3.2223 - val_loss: 17.0779 - val_y1_output_loss: 6.7491 - val_y2_output_loss: 10.8856 - val_y1_output_root_mean_squared_error: 2.5642 - val_y2_output_root_mean_squared_error: 3.2408
# Epoch 21/500
# 614/614 [==============================] - 0s 143us/sample - loss: 16.7590 - y1_output_loss: 6.5715 - y2_output_loss: 10.0751 - y1_output_root_mean_squared_error: 2.5736 - y2_output_root_mean_squared_error: 3.1837 - val_loss: 14.8894 - val_y1_output_loss: 5.9371 - val_y2_output_loss: 9.1402 - val_y1_output_root_mean_squared_error: 2.4081 - val_y2_output_root_mean_squared_error: 3.0151
# Epoch 22/500
# 614/614 [==============================] - 0s 147us/sample - loss: 15.2177 - y1_output_loss: 5.9959 - y2_output_loss: 9.2230 - y1_output_root_mean_squared_error: 2.4449 - y2_output_root_mean_squared_error: 3.0397 - val_loss: 13.5318 - val_y1_output_loss: 5.4616 - val_y2_output_loss: 8.3870 - val_y1_output_root_mean_squared_error: 2.3039 - val_y2_output_root_mean_squared_error: 2.8677
# Epoch 23/500
# 614/614 [==============================] - 0s 148us/sample - loss: 16.9129 - y1_output_loss: 6.2594 - y2_output_loss: 10.5252 - y1_output_root_mean_squared_error: 2.5117 - y2_output_root_mean_squared_error: 3.2564 - val_loss: 13.4478 - val_y1_output_loss: 4.9982 - val_y2_output_loss: 8.6986 - val_y1_output_root_mean_squared_error: 2.2131 - val_y2_output_root_mean_squared_error: 2.9240
# Epoch 24/500
# 614/614 [==============================] - 0s 151us/sample - loss: 13.7527 - y1_output_loss: 5.5517 - y2_output_loss: 8.1895 - y1_output_root_mean_squared_error: 2.3455 - y2_output_root_mean_squared_error: 2.8725 - val_loss: 16.2515 - val_y1_output_loss: 6.6151 - val_y2_output_loss: 10.1635 - val_y1_output_root_mean_squared_error: 2.5295 - val_y2_output_root_mean_squared_error: 3.1390
# Epoch 25/500
# 614/614 [==============================] - 0s 149us/sample - loss: 13.8657 - y1_output_loss: 5.5346 - y2_output_loss: 8.3019 - y1_output_root_mean_squared_error: 2.3559 - y2_output_root_mean_squared_error: 2.8836 - val_loss: 16.9805 - val_y1_output_loss: 4.9371 - val_y2_output_loss: 12.3410 - val_y1_output_root_mean_squared_error: 2.1939 - val_y2_output_root_mean_squared_error: 3.4881
# Epoch 26/500
# 614/614 [==============================] - 0s 163us/sample - loss: 16.3733 - y1_output_loss: 5.8057 - y2_output_loss: 11.0611 - y1_output_root_mean_squared_error: 2.3962 - y2_output_root_mean_squared_error: 3.2606 - val_loss: 19.0297 - val_y1_output_loss: 5.2217 - val_y2_output_loss: 14.7594 - val_y1_output_root_mean_squared_error: 2.2621 - val_y2_output_root_mean_squared_error: 3.7299
# Epoch 27/500
# 614/614 [==============================] - 0s 150us/sample - loss: 14.7003 - y1_output_loss: 5.4813 - y2_output_loss: 9.1240 - y1_output_root_mean_squared_error: 2.3493 - y2_output_root_mean_squared_error: 3.0300 - val_loss: 9.4812 - val_y1_output_loss: 3.4941 - val_y2_output_loss: 6.3695 - val_y1_output_root_mean_squared_error: 1.8606 - val_y2_output_root_mean_squared_error: 2.4535
# Epoch 28/500
# 614/614 [==============================] - 0s 148us/sample - loss: 14.6327 - y1_output_loss: 5.4418 - y2_output_loss: 9.1465 - y1_output_root_mean_squared_error: 2.3373 - y2_output_root_mean_squared_error: 3.0281 - val_loss: 17.0978 - val_y1_output_loss: 5.4201 - val_y2_output_loss: 12.3613 - val_y1_output_root_mean_squared_error: 2.3180 - val_y2_output_root_mean_squared_error: 3.4241
# Epoch 29/500
# 614/614 [==============================] - 0s 147us/sample - loss: 12.2387 - y1_output_loss: 4.6390 - y2_output_loss: 7.5271 - y1_output_root_mean_squared_error: 2.1542 - y2_output_root_mean_squared_error: 2.7564 - val_loss: 9.3112 - val_y1_output_loss: 3.4481 - val_y2_output_loss: 6.1854 - val_y1_output_root_mean_squared_error: 1.8421 - val_y2_output_root_mean_squared_error: 2.4327
# Epoch 30/500
# 614/614 [==============================] - 0s 144us/sample - loss: 14.3408 - y1_output_loss: 4.9327 - y2_output_loss: 9.2848 - y1_output_root_mean_squared_error: 2.2313 - y2_output_root_mean_squared_error: 3.0597 - val_loss: 11.2285 - val_y1_output_loss: 4.1854 - val_y2_output_loss: 7.4738 - val_y1_output_root_mean_squared_error: 2.0390 - val_y2_output_root_mean_squared_error: 2.6591
# Epoch 31/500
# 614/614 [==============================] - 0s 144us/sample - loss: 10.6821 - y1_output_loss: 4.0193 - y2_output_loss: 6.9286 - y1_output_root_mean_squared_error: 1.9868 - y2_output_root_mean_squared_error: 2.5951 - val_loss: 31.8334 - val_y1_output_loss: 7.3299 - val_y2_output_loss: 25.1947 - val_y1_output_root_mean_squared_error: 2.6534 - val_y2_output_root_mean_squared_error: 4.9792
# Epoch 32/500
# 614/614 [==============================] - 0s 152us/sample - loss: 12.1762 - y1_output_loss: 4.2745 - y2_output_loss: 7.8200 - y1_output_root_mean_squared_error: 2.0733 - y2_output_root_mean_squared_error: 2.8067 - val_loss: 13.8422 - val_y1_output_loss: 4.9907 - val_y2_output_loss: 9.2344 - val_y1_output_root_mean_squared_error: 2.2350 - val_y2_output_root_mean_squared_error: 2.9744
# Epoch 33/500
# 614/614 [==============================] - 0s 147us/sample - loss: 9.8018 - y1_output_loss: 3.9166 - y2_output_loss: 5.8671 - y1_output_root_mean_squared_error: 1.9710 - y2_output_root_mean_squared_error: 2.4325 - val_loss: 10.2738 - val_y1_output_loss: 4.2841 - val_y2_output_loss: 6.4736 - val_y1_output_root_mean_squared_error: 2.0575 - val_y2_output_root_mean_squared_error: 2.4577
# Epoch 34/500
# 614/614 [==============================] - 0s 145us/sample - loss: 10.5331 - y1_output_loss: 4.0331 - y2_output_loss: 6.4107 - y1_output_root_mean_squared_error: 2.0162 - y2_output_root_mean_squared_error: 2.5433 - val_loss: 11.4510 - val_y1_output_loss: 3.7507 - val_y2_output_loss: 8.1717 - val_y1_output_root_mean_squared_error: 1.9337 - val_y2_output_root_mean_squared_error: 2.7771
# Epoch 35/500
# 614/614 [==============================] - 0s 143us/sample - loss: 9.5706 - y1_output_loss: 3.4353 - y2_output_loss: 6.3697 - y1_output_root_mean_squared_error: 1.8518 - y2_output_root_mean_squared_error: 2.4782 - val_loss: 26.7785 - val_y1_output_loss: 5.8779 - val_y2_output_loss: 21.9113 - val_y1_output_root_mean_squared_error: 2.4325 - val_y2_output_root_mean_squared_error: 4.5674
# Epoch 36/500
# 614/614 [==============================] - 0s 141us/sample - loss: 10.3032 - y1_output_loss: 3.5550 - y2_output_loss: 6.6678 - y1_output_root_mean_squared_error: 1.8904 - y2_output_root_mean_squared_error: 2.5942 - val_loss: 13.2552 - val_y1_output_loss: 4.7641 - val_y2_output_loss: 8.8564 - val_y1_output_root_mean_squared_error: 2.1624 - val_y2_output_root_mean_squared_error: 2.9290
# Epoch 37/500
# 614/614 [==============================] - 0s 143us/sample - loss: 9.4237 - y1_output_loss: 3.2856 - y2_output_loss: 6.0886 - y1_output_root_mean_squared_error: 1.8115 - y2_output_root_mean_squared_error: 2.4783 - val_loss: 10.0756 - val_y1_output_loss: 3.1346 - val_y2_output_loss: 7.2317 - val_y1_output_root_mean_squared_error: 1.7521 - val_y2_output_root_mean_squared_error: 2.6468
# Epoch 38/500
# 614/614 [==============================] - 0s 146us/sample - loss: 8.6187 - y1_output_loss: 3.0125 - y2_output_loss: 5.5892 - y1_output_root_mean_squared_error: 1.7260 - y2_output_root_mean_squared_error: 2.3748 - val_loss: 7.6824 - val_y1_output_loss: 2.4281 - val_y2_output_loss: 5.5317 - val_y1_output_root_mean_squared_error: 1.5554 - val_y2_output_root_mean_squared_error: 2.2941
# Epoch 39/500
# 614/614 [==============================] - 0s 145us/sample - loss: 8.0997 - y1_output_loss: 2.9726 - y2_output_loss: 5.1937 - y1_output_root_mean_squared_error: 1.7120 - y2_output_root_mean_squared_error: 2.2735 - val_loss: 11.5670 - val_y1_output_loss: 3.4861 - val_y2_output_loss: 8.4540 - val_y1_output_root_mean_squared_error: 1.8356 - val_y2_output_root_mean_squared_error: 2.8631
# Epoch 40/500
# 614/614 [==============================] - 0s 141us/sample - loss: 7.7691 - y1_output_loss: 2.7379 - y2_output_loss: 4.9855 - y1_output_root_mean_squared_error: 1.6613 - y2_output_root_mean_squared_error: 2.2381 - val_loss: 7.6029 - val_y1_output_loss: 2.4933 - val_y2_output_loss: 5.5063 - val_y1_output_root_mean_squared_error: 1.5650 - val_y2_output_root_mean_squared_error: 2.2702
# Epoch 41/500
# 614/614 [==============================] - 0s 143us/sample - loss: 9.1756 - y1_output_loss: 2.9941 - y2_output_loss: 6.2289 - y1_output_root_mean_squared_error: 1.7295 - y2_output_root_mean_squared_error: 2.4868 - val_loss: 8.9830 - val_y1_output_loss: 2.7700 - val_y2_output_loss: 6.4814 - val_y1_output_root_mean_squared_error: 1.6648 - val_y2_output_root_mean_squared_error: 2.4923
# Epoch 42/500
# 614/614 [==============================] - 0s 147us/sample - loss: 10.6848 - y1_output_loss: 3.4716 - y2_output_loss: 7.1557 - y1_output_root_mean_squared_error: 1.8634 - y2_output_root_mean_squared_error: 2.6856 - val_loss: 6.4601 - val_y1_output_loss: 1.7167 - val_y2_output_loss: 5.0713 - val_y1_output_root_mean_squared_error: 1.3220 - val_y2_output_root_mean_squared_error: 2.1708
# Epoch 43/500
# 614/614 [==============================] - 0s 144us/sample - loss: 8.3140 - y1_output_loss: 2.7268 - y2_output_loss: 5.5938 - y1_output_root_mean_squared_error: 1.6562 - y2_output_root_mean_squared_error: 2.3603 - val_loss: 9.6692 - val_y1_output_loss: 3.3666 - val_y2_output_loss: 6.8105 - val_y1_output_root_mean_squared_error: 1.8342 - val_y2_output_root_mean_squared_error: 2.5109
# Epoch 44/500
# 614/614 [==============================] - 0s 151us/sample - loss: 8.3100 - y1_output_loss: 2.8525 - y2_output_loss: 5.4984 - y1_output_root_mean_squared_error: 1.6885 - y2_output_root_mean_squared_error: 2.3365 - val_loss: 19.5887 - val_y1_output_loss: 4.6678 - val_y2_output_loss: 14.8940 - val_y1_output_root_mean_squared_error: 2.1710 - val_y2_output_root_mean_squared_error: 3.8568
# Epoch 45/500
# 614/614 [==============================] - 0s 143us/sample - loss: 9.8579 - y1_output_loss: 3.3971 - y2_output_loss: 6.4454 - y1_output_root_mean_squared_error: 1.8382 - y2_output_root_mean_squared_error: 2.5454 - val_loss: 11.0798 - val_y1_output_loss: 3.1503 - val_y2_output_loss: 8.1327 - val_y1_output_root_mean_squared_error: 1.7770 - val_y2_output_root_mean_squared_error: 2.8146
# Epoch 46/500
# 614/614 [==============================] - 0s 144us/sample - loss: 7.8249 - y1_output_loss: 2.6870 - y2_output_loss: 5.0831 - y1_output_root_mean_squared_error: 1.6419 - y2_output_root_mean_squared_error: 2.2648 - val_loss: 7.1788 - val_y1_output_loss: 2.1559 - val_y2_output_loss: 5.3073 - val_y1_output_root_mean_squared_error: 1.4662 - val_y2_output_root_mean_squared_error: 2.2426
# Epoch 47/500
# 614/614 [==============================] - 0s 140us/sample - loss: 10.4877 - y1_output_loss: 3.5011 - y2_output_loss: 6.9348 - y1_output_root_mean_squared_error: 1.8740 - y2_output_root_mean_squared_error: 2.6411 - val_loss: 12.2793 - val_y1_output_loss: 3.6410 - val_y2_output_loss: 9.0594 - val_y1_output_root_mean_squared_error: 1.9233 - val_y2_output_root_mean_squared_error: 2.9292
# Epoch 48/500
# 614/614 [==============================] - 0s 144us/sample - loss: 9.4096 - y1_output_loss: 2.9913 - y2_output_loss: 6.3502 - y1_output_root_mean_squared_error: 1.7370 - y2_output_root_mean_squared_error: 2.5284 - val_loss: 7.0073 - val_y1_output_loss: 2.2128 - val_y2_output_loss: 5.1756 - val_y1_output_root_mean_squared_error: 1.4898 - val_y2_output_root_mean_squared_error: 2.1881
# Epoch 49/500
# 614/614 [==============================] - 0s 140us/sample - loss: 6.6718 - y1_output_loss: 2.2670 - y2_output_loss: 4.3442 - y1_output_root_mean_squared_error: 1.5127 - y2_output_root_mean_squared_error: 2.0937 - val_loss: 6.5678 - val_y1_output_loss: 1.8381 - val_y2_output_loss: 4.9816 - val_y1_output_root_mean_squared_error: 1.3613 - val_y2_output_root_mean_squared_error: 2.1714
# Epoch 50/500
# 614/614 [==============================] - 0s 138us/sample - loss: 6.7609 - y1_output_loss: 2.3520 - y2_output_loss: 4.4333 - y1_output_root_mean_squared_error: 1.5248 - y2_output_root_mean_squared_error: 2.1061 - val_loss: 6.3337 - val_y1_output_loss: 1.5947 - val_y2_output_loss: 4.9432 - val_y1_output_root_mean_squared_error: 1.2696 - val_y2_output_root_mean_squared_error: 2.1730
# Epoch 51/500
# 614/614 [==============================] - 0s 143us/sample - loss: 6.5208 - y1_output_loss: 2.0496 - y2_output_loss: 4.5902 - y1_output_root_mean_squared_error: 1.4342 - y2_output_root_mean_squared_error: 2.1128 - val_loss: 9.0381 - val_y1_output_loss: 2.1606 - val_y2_output_loss: 7.2421 - val_y1_output_root_mean_squared_error: 1.4831 - val_y2_output_root_mean_squared_error: 2.6151
# Epoch 52/500
# 614/614 [==============================] - 0s 148us/sample - loss: 7.6606 - y1_output_loss: 2.3729 - y2_output_loss: 5.2347 - y1_output_root_mean_squared_error: 1.5467 - y2_output_root_mean_squared_error: 2.2953 - val_loss: 7.9172 - val_y1_output_loss: 2.5976 - val_y2_output_loss: 5.5451 - val_y1_output_root_mean_squared_error: 1.6168 - val_y2_output_root_mean_squared_error: 2.3028
# Epoch 53/500
# 614/614 [==============================] - 0s 146us/sample - loss: 7.1505 - y1_output_loss: 2.2806 - y2_output_loss: 4.8151 - y1_output_root_mean_squared_error: 1.5155 - y2_output_root_mean_squared_error: 2.2031 - val_loss: 9.7040 - val_y1_output_loss: 3.5474 - val_y2_output_loss: 6.4352 - val_y1_output_root_mean_squared_error: 1.9001 - val_y2_output_root_mean_squared_error: 2.4685
# Epoch 54/500
# 614/614 [==============================] - 0s 145us/sample - loss: 8.4022 - y1_output_loss: 2.7899 - y2_output_loss: 5.5923 - y1_output_root_mean_squared_error: 1.6723 - y2_output_root_mean_squared_error: 2.3676 - val_loss: 7.1813 - val_y1_output_loss: 1.8623 - val_y2_output_loss: 5.5135 - val_y1_output_root_mean_squared_error: 1.3690 - val_y2_output_root_mean_squared_error: 2.3037
# Epoch 55/500
# 614/614 [==============================] - 0s 142us/sample - loss: 6.7686 - y1_output_loss: 2.3239 - y2_output_loss: 4.3865 - y1_output_root_mean_squared_error: 1.5304 - y2_output_root_mean_squared_error: 2.1039 - val_loss: 6.3026 - val_y1_output_loss: 1.8478 - val_y2_output_loss: 4.6267 - val_y1_output_root_mean_squared_error: 1.3706 - val_y2_output_root_mean_squared_error: 2.1034
# Epoch 56/500
# 614/614 [==============================] - 0s 144us/sample - loss: 6.9735 - y1_output_loss: 2.2348 - y2_output_loss: 4.6901 - y1_output_root_mean_squared_error: 1.4989 - y2_output_root_mean_squared_error: 2.1741 - val_loss: 8.7527 - val_y1_output_loss: 2.1921 - val_y2_output_loss: 6.7140 - val_y1_output_root_mean_squared_error: 1.4774 - val_y2_output_root_mean_squared_error: 2.5632
# Epoch 57/500
# 614/614 [==============================] - 0s 146us/sample - loss: 9.4651 - y1_output_loss: 2.8752 - y2_output_loss: 6.5200 - y1_output_root_mean_squared_error: 1.6994 - y2_output_root_mean_squared_error: 2.5646 - val_loss: 9.0216 - val_y1_output_loss: 2.1829 - val_y2_output_loss: 6.8359 - val_y1_output_root_mean_squared_error: 1.4971 - val_y2_output_root_mean_squared_error: 2.6039
# Epoch 58/500
# 614/614 [==============================] - 0s 138us/sample - loss: 7.2310 - y1_output_loss: 2.3650 - y2_output_loss: 4.8454 - y1_output_root_mean_squared_error: 1.5379 - y2_output_root_mean_squared_error: 2.2059 - val_loss: 10.0106 - val_y1_output_loss: 2.1131 - val_y2_output_loss: 7.9693 - val_y1_output_root_mean_squared_error: 1.4603 - val_y2_output_root_mean_squared_error: 2.8068
# Epoch 59/500
# 614/614 [==============================] - 0s 139us/sample - loss: 7.7531 - y1_output_loss: 2.4708 - y2_output_loss: 5.2541 - y1_output_root_mean_squared_error: 1.5753 - y2_output_root_mean_squared_error: 2.2959 - val_loss: 9.4203 - val_y1_output_loss: 3.2018 - val_y2_output_loss: 6.3719 - val_y1_output_root_mean_squared_error: 1.8101 - val_y2_output_root_mean_squared_error: 2.4787
# Epoch 60/500
# 614/614 [==============================] - 0s 144us/sample - loss: 6.4187 - y1_output_loss: 2.1879 - y2_output_loss: 4.3144 - y1_output_root_mean_squared_error: 1.4766 - y2_output_root_mean_squared_error: 2.0587 - val_loss: 23.7389 - val_y1_output_loss: 8.9624 - val_y2_output_loss: 14.6303 - val_y1_output_root_mean_squared_error: 3.0374 - val_y2_output_root_mean_squared_error: 3.8096
# Epoch 61/500
# 614/614 [==============================] - 0s 145us/sample - loss: 12.8419 - y1_output_loss: 4.8637 - y2_output_loss: 7.8622 - y1_output_root_mean_squared_error: 2.2156 - y2_output_root_mean_squared_error: 2.8166 - val_loss: 5.6575 - val_y1_output_loss: 1.4982 - val_y2_output_loss: 4.3146 - val_y1_output_root_mean_squared_error: 1.2339 - val_y2_output_root_mean_squared_error: 2.0335
# Epoch 62/500
# 614/614 [==============================] - 0s 145us/sample - loss: 6.1212 - y1_output_loss: 2.0374 - y2_output_loss: 4.1086 - y1_output_root_mean_squared_error: 1.4263 - y2_output_root_mean_squared_error: 2.0216 - val_loss: 18.0430 - val_y1_output_loss: 4.0313 - val_y2_output_loss: 14.1106 - val_y1_output_root_mean_squared_error: 1.9948 - val_y2_output_root_mean_squared_error: 3.7501
# Epoch 63/500
# 614/614 [==============================] - 0s 146us/sample - loss: 9.0913 - y1_output_loss: 3.0298 - y2_output_loss: 6.0709 - y1_output_root_mean_squared_error: 1.7377 - y2_output_root_mean_squared_error: 2.4641 - val_loss: 14.1386 - val_y1_output_loss: 3.2076 - val_y2_output_loss: 10.9351 - val_y1_output_root_mean_squared_error: 1.7944 - val_y2_output_root_mean_squared_error: 3.3044
# Epoch 64/500
# 614/614 [==============================] - 0s 144us/sample - loss: 6.0788 - y1_output_loss: 2.0036 - y2_output_loss: 4.0203 - y1_output_root_mean_squared_error: 1.4216 - y2_output_root_mean_squared_error: 2.0144 - val_loss: 6.4600 - val_y1_output_loss: 1.7494 - val_y2_output_loss: 4.8709 - val_y1_output_root_mean_squared_error: 1.3231 - val_y2_output_root_mean_squared_error: 2.1701
# Epoch 65/500
# 614/614 [==============================] - 0s 147us/sample - loss: 7.2212 - y1_output_loss: 2.3357 - y2_output_loss: 4.8946 - y1_output_root_mean_squared_error: 1.5231 - y2_output_root_mean_squared_error: 2.2139 - val_loss: 8.0647 - val_y1_output_loss: 2.2717 - val_y2_output_loss: 6.0850 - val_y1_output_root_mean_squared_error: 1.4995 - val_y2_output_root_mean_squared_error: 2.4117
# Epoch 66/500
# 614/614 [==============================] - 0s 140us/sample - loss: 6.4075 - y1_output_loss: 2.0702 - y2_output_loss: 4.3354 - y1_output_root_mean_squared_error: 1.4424 - y2_output_root_mean_squared_error: 2.0802 - val_loss: 5.2188 - val_y1_output_loss: 1.3361 - val_y2_output_loss: 4.0704 - val_y1_output_root_mean_squared_error: 1.1648 - val_y2_output_root_mean_squared_error: 1.9652
# Epoch 67/500
# 614/614 [==============================] - 0s 136us/sample - loss: 6.7077 - y1_output_loss: 2.0734 - y2_output_loss: 4.5994 - y1_output_root_mean_squared_error: 1.4393 - y2_output_root_mean_squared_error: 2.1532 - val_loss: 6.3566 - val_y1_output_loss: 1.5446 - val_y2_output_loss: 4.9134 - val_y1_output_root_mean_squared_error: 1.2553 - val_y2_output_root_mean_squared_error: 2.1865
# Epoch 68/500
# 614/614 [==============================] - 0s 142us/sample - loss: 5.8731 - y1_output_loss: 1.7295 - y2_output_loss: 4.0989 - y1_output_root_mean_squared_error: 1.3205 - y2_output_root_mean_squared_error: 2.0321 - val_loss: 6.3744 - val_y1_output_loss: 1.9319 - val_y2_output_loss: 4.5656 - val_y1_output_root_mean_squared_error: 1.3900 - val_y2_output_root_mean_squared_error: 2.1077
# Epoch 69/500
# 614/614 [==============================] - 0s 145us/sample - loss: 5.5576 - y1_output_loss: 1.8241 - y2_output_loss: 3.6874 - y1_output_root_mean_squared_error: 1.3560 - y2_output_root_mean_squared_error: 1.9285 - val_loss: 5.4176 - val_y1_output_loss: 1.3548 - val_y2_output_loss: 4.1779 - val_y1_output_root_mean_squared_error: 1.1732 - val_y2_output_root_mean_squared_error: 2.0103
# Epoch 70/500
# 614/614 [==============================] - 0s 145us/sample - loss: 6.1118 - y1_output_loss: 1.8324 - y2_output_loss: 4.4018 - y1_output_root_mean_squared_error: 1.3479 - y2_output_root_mean_squared_error: 2.0724 - val_loss: 9.8002 - val_y1_output_loss: 3.1253 - val_y2_output_loss: 6.8546 - val_y1_output_root_mean_squared_error: 1.7505 - val_y2_output_root_mean_squared_error: 2.5953
# Epoch 71/500
# 614/614 [==============================] - 0s 152us/sample - loss: 4.8693 - y1_output_loss: 1.5182 - y2_output_loss: 3.3415 - y1_output_root_mean_squared_error: 1.2362 - y2_output_root_mean_squared_error: 1.8279 - val_loss: 7.1878 - val_y1_output_loss: 1.4082 - val_y2_output_loss: 5.8134 - val_y1_output_root_mean_squared_error: 1.1990 - val_y2_output_root_mean_squared_error: 2.3980
# Epoch 72/500
# 614/614 [==============================] - 0s 149us/sample - loss: 4.9255 - y1_output_loss: 1.5651 - y2_output_loss: 3.3722 - y1_output_root_mean_squared_error: 1.2546 - y2_output_root_mean_squared_error: 1.8307 - val_loss: 14.3305 - val_y1_output_loss: 2.2819 - val_y2_output_loss: 12.8024 - val_y1_output_root_mean_squared_error: 1.5102 - val_y2_output_root_mean_squared_error: 3.4713
# Epoch 73/500
# 614/614 [==============================] - 0s 146us/sample - loss: 6.6164 - y1_output_loss: 1.7153 - y2_output_loss: 4.8617 - y1_output_root_mean_squared_error: 1.3147 - y2_output_root_mean_squared_error: 2.2109 - val_loss: 4.3766 - val_y1_output_loss: 1.1514 - val_y2_output_loss: 3.3400 - val_y1_output_root_mean_squared_error: 1.0837 - val_y2_output_root_mean_squared_error: 1.7895
# Epoch 74/500
# 614/614 [==============================] - 0s 146us/sample - loss: 5.1574 - y1_output_loss: 1.5838 - y2_output_loss: 3.5700 - y1_output_root_mean_squared_error: 1.2597 - y2_output_root_mean_squared_error: 1.8896 - val_loss: 7.2162 - val_y1_output_loss: 2.1069 - val_y2_output_loss: 5.3992 - val_y1_output_root_mean_squared_error: 1.4629 - val_y2_output_root_mean_squared_error: 2.2530
# Epoch 75/500
# 614/614 [==============================] - 0s 141us/sample - loss: 5.6600 - y1_output_loss: 1.6817 - y2_output_loss: 3.9383 - y1_output_root_mean_squared_error: 1.3005 - y2_output_root_mean_squared_error: 1.9922 - val_loss: 4.5577 - val_y1_output_loss: 1.2501 - val_y2_output_loss: 3.4567 - val_y1_output_root_mean_squared_error: 1.1318 - val_y2_output_root_mean_squared_error: 1.8102
# Epoch 76/500
# 614/614 [==============================] - 0s 148us/sample - loss: 3.8869 - y1_output_loss: 1.1786 - y2_output_loss: 2.7074 - y1_output_root_mean_squared_error: 1.0796 - y2_output_root_mean_squared_error: 1.6497 - val_loss: 7.0598 - val_y1_output_loss: 1.6995 - val_y2_output_loss: 5.3997 - val_y1_output_root_mean_squared_error: 1.3109 - val_y2_output_root_mean_squared_error: 2.3111
# Epoch 77/500
# 614/614 [==============================] - 0s 139us/sample - loss: 4.6325 - y1_output_loss: 1.2760 - y2_output_loss: 3.3532 - y1_output_root_mean_squared_error: 1.1342 - y2_output_root_mean_squared_error: 1.8292 - val_loss: 3.9877 - val_y1_output_loss: 0.8536 - val_y2_output_loss: 3.2205 - val_y1_output_root_mean_squared_error: 0.9397 - val_y2_output_root_mean_squared_error: 1.7620
# Epoch 78/500
# 614/614 [==============================] - 0s 142us/sample - loss: 4.0501 - y1_output_loss: 1.2061 - y2_output_loss: 2.8226 - y1_output_root_mean_squared_error: 1.1025 - y2_output_root_mean_squared_error: 1.6836 - val_loss: 3.8483 - val_y1_output_loss: 0.9929 - val_y2_output_loss: 3.0131 - val_y1_output_root_mean_squared_error: 1.0090 - val_y2_output_root_mean_squared_error: 1.6823
# Epoch 79/500
# 614/614 [==============================] - 0s 145us/sample - loss: 5.8947 - y1_output_loss: 1.8162 - y2_output_loss: 4.0518 - y1_output_root_mean_squared_error: 1.3525 - y2_output_root_mean_squared_error: 2.0163 - val_loss: 5.1255 - val_y1_output_loss: 1.2961 - val_y2_output_loss: 4.0339 - val_y1_output_root_mean_squared_error: 1.1466 - val_y2_output_root_mean_squared_error: 1.9521
# Epoch 80/500
# 614/614 [==============================] - 0s 142us/sample - loss: 5.6055 - y1_output_loss: 1.7171 - y2_output_loss: 3.8614 - y1_output_root_mean_squared_error: 1.3139 - y2_output_root_mean_squared_error: 1.9696 - val_loss: 3.1526 - val_y1_output_loss: 0.7184 - val_y2_output_loss: 2.5220 - val_y1_output_root_mean_squared_error: 0.8566 - val_y2_output_root_mean_squared_error: 1.5553
# Epoch 81/500
# 614/614 [==============================] - 0s 145us/sample - loss: 3.5643 - y1_output_loss: 1.0577 - y2_output_loss: 2.5486 - y1_output_root_mean_squared_error: 1.0132 - y2_output_root_mean_squared_error: 1.5930 - val_loss: 4.0787 - val_y1_output_loss: 1.1494 - val_y2_output_loss: 3.0129 - val_y1_output_root_mean_squared_error: 1.0839 - val_y2_output_root_mean_squared_error: 1.7041
# Epoch 82/500
# 614/614 [==============================] - 0s 147us/sample - loss: 3.7147 - y1_output_loss: 1.0545 - y2_output_loss: 2.6406 - y1_output_root_mean_squared_error: 1.0249 - y2_output_root_mean_squared_error: 1.6322 - val_loss: 3.8808 - val_y1_output_loss: 1.4058 - val_y2_output_loss: 2.5627 - val_y1_output_root_mean_squared_error: 1.1996 - val_y2_output_root_mean_squared_error: 1.5626
# Epoch 83/500
# 614/614 [==============================] - 0s 147us/sample - loss: 4.1426 - y1_output_loss: 1.2014 - y2_output_loss: 2.9279 - y1_output_root_mean_squared_error: 1.0958 - y2_output_root_mean_squared_error: 1.7152 - val_loss: 3.4759 - val_y1_output_loss: 0.8761 - val_y2_output_loss: 2.5886 - val_y1_output_root_mean_squared_error: 0.9418 - val_y2_output_root_mean_squared_error: 1.6090
# Epoch 84/500
# 614/614 [==============================] - 0s 146us/sample - loss: 7.3427 - y1_output_loss: 2.6518 - y2_output_loss: 4.6351 - y1_output_root_mean_squared_error: 1.6340 - y2_output_root_mean_squared_error: 2.1617 - val_loss: 3.0645 - val_y1_output_loss: 0.6561 - val_y2_output_loss: 2.4504 - val_y1_output_root_mean_squared_error: 0.8190 - val_y2_output_root_mean_squared_error: 1.5471
# Epoch 85/500
# 614/614 [==============================] - 0s 144us/sample - loss: 3.1920 - y1_output_loss: 0.8379 - y2_output_loss: 2.3534 - y1_output_root_mean_squared_error: 0.9085 - y2_output_root_mean_squared_error: 1.5384 - val_loss: 3.6311 - val_y1_output_loss: 1.1341 - val_y2_output_loss: 2.5656 - val_y1_output_root_mean_squared_error: 1.0739 - val_y2_output_root_mean_squared_error: 1.5741
# Epoch 86/500
# 614/614 [==============================] - 0s 146us/sample - loss: 2.9634 - y1_output_loss: 0.7993 - y2_output_loss: 2.2556 - y1_output_root_mean_squared_error: 0.8829 - y2_output_root_mean_squared_error: 1.4778 - val_loss: 53.2736 - val_y1_output_loss: 16.4212 - val_y2_output_loss: 35.7590 - val_y1_output_root_mean_squared_error: 4.0964 - val_y2_output_root_mean_squared_error: 6.0410
# Epoch 87/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.5246 - y1_output_loss: 1.2709 - y2_output_loss: 3.2113 - y1_output_root_mean_squared_error: 1.1325 - y2_output_root_mean_squared_error: 1.8005 - val_loss: 2.9739 - val_y1_output_loss: 0.6627 - val_y2_output_loss: 2.3778 - val_y1_output_root_mean_squared_error: 0.8271 - val_y2_output_root_mean_squared_error: 1.5132
# Epoch 88/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.4019 - y1_output_loss: 0.8934 - y2_output_loss: 2.4835 - y1_output_root_mean_squared_error: 0.9468 - y2_output_root_mean_squared_error: 1.5829 - val_loss: 3.8173 - val_y1_output_loss: 0.9314 - val_y2_output_loss: 3.0298 - val_y1_output_root_mean_squared_error: 0.9764 - val_y2_output_root_mean_squared_error: 1.6923
# Epoch 89/500
# 614/614 [==============================] - 0s 144us/sample - loss: 2.8966 - y1_output_loss: 0.7718 - y2_output_loss: 2.1648 - y1_output_root_mean_squared_error: 0.8794 - y2_output_root_mean_squared_error: 1.4571 - val_loss: 4.2875 - val_y1_output_loss: 0.9093 - val_y2_output_loss: 3.7147 - val_y1_output_root_mean_squared_error: 0.9514 - val_y2_output_root_mean_squared_error: 1.8391
# Epoch 90/500
# 614/614 [==============================] - 0s 147us/sample - loss: 2.7464 - y1_output_loss: 0.6321 - y2_output_loss: 2.1510 - y1_output_root_mean_squared_error: 0.7966 - y2_output_root_mean_squared_error: 1.4532 - val_loss: 3.7344 - val_y1_output_loss: 0.5173 - val_y2_output_loss: 3.1966 - val_y1_output_root_mean_squared_error: 0.7244 - val_y2_output_root_mean_squared_error: 1.7916
# Epoch 91/500
# 614/614 [==============================] - 0s 148us/sample - loss: 3.3236 - y1_output_loss: 0.7799 - y2_output_loss: 2.5211 - y1_output_root_mean_squared_error: 0.8858 - y2_output_root_mean_squared_error: 1.5934 - val_loss: 3.2198 - val_y1_output_loss: 0.8515 - val_y2_output_loss: 2.3808 - val_y1_output_root_mean_squared_error: 0.9332 - val_y2_output_root_mean_squared_error: 1.5326
# Epoch 92/500
# 614/614 [==============================] - 0s 157us/sample - loss: 2.5743 - y1_output_loss: 0.6939 - y2_output_loss: 1.8704 - y1_output_root_mean_squared_error: 0.8330 - y2_output_root_mean_squared_error: 1.3713 - val_loss: 3.1019 - val_y1_output_loss: 0.6992 - val_y2_output_loss: 2.4514 - val_y1_output_root_mean_squared_error: 0.8504 - val_y2_output_root_mean_squared_error: 1.5423
# Epoch 93/500
# 614/614 [==============================] - 0s 163us/sample - loss: 2.7273 - y1_output_loss: 0.6680 - y2_output_loss: 2.1086 - y1_output_root_mean_squared_error: 0.8204 - y2_output_root_mean_squared_error: 1.4333 - val_loss: 5.2855 - val_y1_output_loss: 0.9156 - val_y2_output_loss: 4.7735 - val_y1_output_root_mean_squared_error: 0.9598 - val_y2_output_root_mean_squared_error: 2.0891
# Epoch 94/500
# 614/614 [==============================] - 0s 146us/sample - loss: 2.4357 - y1_output_loss: 0.6701 - y2_output_loss: 1.7485 - y1_output_root_mean_squared_error: 0.8207 - y2_output_root_mean_squared_error: 1.3274 - val_loss: 3.1484 - val_y1_output_loss: 0.5870 - val_y2_output_loss: 2.5779 - val_y1_output_root_mean_squared_error: 0.7728 - val_y2_output_root_mean_squared_error: 1.5973
# Epoch 95/500
# 614/614 [==============================] - 0s 145us/sample - loss: 2.3877 - y1_output_loss: 0.5576 - y2_output_loss: 1.8381 - y1_output_root_mean_squared_error: 0.7494 - y2_output_root_mean_squared_error: 1.3513 - val_loss: 5.2003 - val_y1_output_loss: 0.4049 - val_y2_output_loss: 4.7361 - val_y1_output_root_mean_squared_error: 0.6430 - val_y2_output_root_mean_squared_error: 2.1879
# Epoch 96/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.6023 - y1_output_loss: 0.7073 - y2_output_loss: 1.9073 - y1_output_root_mean_squared_error: 0.8293 - y2_output_root_mean_squared_error: 1.3837 - val_loss: 3.2975 - val_y1_output_loss: 0.9453 - val_y2_output_loss: 2.4103 - val_y1_output_root_mean_squared_error: 0.9888 - val_y2_output_root_mean_squared_error: 1.5231
# Epoch 97/500
# 614/614 [==============================] - 0s 146us/sample - loss: 2.6196 - y1_output_loss: 0.6134 - y2_output_loss: 1.9854 - y1_output_root_mean_squared_error: 0.7855 - y2_output_root_mean_squared_error: 1.4151 - val_loss: 2.5679 - val_y1_output_loss: 0.5115 - val_y2_output_loss: 2.1493 - val_y1_output_root_mean_squared_error: 0.7268 - val_y2_output_root_mean_squared_error: 1.4282
# Epoch 98/500
# 614/614 [==============================] - 0s 139us/sample - loss: 7.1076 - y1_output_loss: 2.1843 - y2_output_loss: 4.8719 - y1_output_root_mean_squared_error: 1.4847 - y2_output_root_mean_squared_error: 2.2143 - val_loss: 2.5849 - val_y1_output_loss: 0.5485 - val_y2_output_loss: 2.1342 - val_y1_output_root_mean_squared_error: 0.7525 - val_y2_output_root_mean_squared_error: 1.4208
# Epoch 99/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.0806 - y1_output_loss: 0.8202 - y2_output_loss: 2.2370 - y1_output_root_mean_squared_error: 0.9083 - y2_output_root_mean_squared_error: 1.5019 - val_loss: 2.4689 - val_y1_output_loss: 0.4923 - val_y2_output_loss: 2.0363 - val_y1_output_root_mean_squared_error: 0.7074 - val_y2_output_root_mean_squared_error: 1.4030
# Epoch 100/500
# 614/614 [==============================] - 0s 143us/sample - loss: 2.5989 - y1_output_loss: 0.6146 - y2_output_loss: 1.9667 - y1_output_root_mean_squared_error: 0.7842 - y2_output_root_mean_squared_error: 1.4085 - val_loss: 2.6193 - val_y1_output_loss: 0.5034 - val_y2_output_loss: 2.1573 - val_y1_output_root_mean_squared_error: 0.7188 - val_y2_output_root_mean_squared_error: 1.4501
# Epoch 101/500
# 614/614 [==============================] - 0s 153us/sample - loss: 3.1121 - y1_output_loss: 0.7508 - y2_output_loss: 2.6154 - y1_output_root_mean_squared_error: 0.8406 - y2_output_root_mean_squared_error: 1.5509 - val_loss: 8.0842 - val_y1_output_loss: 2.3516 - val_y2_output_loss: 5.7044 - val_y1_output_root_mean_squared_error: 1.5480 - val_y2_output_root_mean_squared_error: 2.3849
# Epoch 102/500
# 614/614 [==============================] - 0s 146us/sample - loss: 3.0674 - y1_output_loss: 0.8238 - y2_output_loss: 2.2304 - y1_output_root_mean_squared_error: 0.9087 - y2_output_root_mean_squared_error: 1.4972 - val_loss: 3.2916 - val_y1_output_loss: 1.0074 - val_y2_output_loss: 2.4358 - val_y1_output_root_mean_squared_error: 1.0118 - val_y2_output_root_mean_squared_error: 1.5060
# Epoch 103/500
# 614/614 [==============================] - 0s 149us/sample - loss: 2.9670 - y1_output_loss: 0.6716 - y2_output_loss: 2.2750 - y1_output_root_mean_squared_error: 0.8191 - y2_output_root_mean_squared_error: 1.5153 - val_loss: 3.6496 - val_y1_output_loss: 0.8739 - val_y2_output_loss: 2.7533 - val_y1_output_root_mean_squared_error: 0.9420 - val_y2_output_root_mean_squared_error: 1.6620
# Epoch 104/500
# 614/614 [==============================] - 0s 171us/sample - loss: 2.2814 - y1_output_loss: 0.5869 - y2_output_loss: 1.6814 - y1_output_root_mean_squared_error: 0.7667 - y2_output_root_mean_squared_error: 1.3014 - val_loss: 3.2882 - val_y1_output_loss: 0.7946 - val_y2_output_loss: 2.6280 - val_y1_output_root_mean_squared_error: 0.9034 - val_y2_output_root_mean_squared_error: 1.5723
# Epoch 105/500
# 614/614 [==============================] - 0s 144us/sample - loss: 2.4914 - y1_output_loss: 0.6109 - y2_output_loss: 1.8680 - y1_output_root_mean_squared_error: 0.7846 - y2_output_root_mean_squared_error: 1.3696 - val_loss: 3.8301 - val_y1_output_loss: 0.6302 - val_y2_output_loss: 3.1744 - val_y1_output_root_mean_squared_error: 0.8079 - val_y2_output_root_mean_squared_error: 1.7825
# Epoch 106/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.3134 - y1_output_loss: 0.6070 - y2_output_loss: 1.7157 - y1_output_root_mean_squared_error: 0.7741 - y2_output_root_mean_squared_error: 1.3092 - val_loss: 2.8625 - val_y1_output_loss: 0.5095 - val_y2_output_loss: 2.3713 - val_y1_output_root_mean_squared_error: 0.7267 - val_y2_output_root_mean_squared_error: 1.5279
# Epoch 107/500
# 614/614 [==============================] - 0s 143us/sample - loss: 2.9942 - y1_output_loss: 0.7201 - y2_output_loss: 2.3047 - y1_output_root_mean_squared_error: 0.8499 - y2_output_root_mean_squared_error: 1.5073 - val_loss: 2.7910 - val_y1_output_loss: 0.9359 - val_y2_output_loss: 1.9572 - val_y1_output_root_mean_squared_error: 0.9716 - val_y2_output_root_mean_squared_error: 1.3591
# Epoch 108/500
# 614/614 [==============================] - 0s 146us/sample - loss: 2.0025 - y1_output_loss: 0.5153 - y2_output_loss: 1.4721 - y1_output_root_mean_squared_error: 0.7194 - y2_output_root_mean_squared_error: 1.2186 - val_loss: 2.0574 - val_y1_output_loss: 0.3860 - val_y2_output_loss: 1.7463 - val_y1_output_root_mean_squared_error: 0.6320 - val_y2_output_root_mean_squared_error: 1.2876
# Epoch 109/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.3119 - y1_output_loss: 0.5619 - y2_output_loss: 1.7403 - y1_output_root_mean_squared_error: 0.7532 - y2_output_root_mean_squared_error: 1.3209 - val_loss: 4.1248 - val_y1_output_loss: 0.3455 - val_y2_output_loss: 3.7621 - val_y1_output_root_mean_squared_error: 0.5969 - val_y2_output_root_mean_squared_error: 1.9412
# Epoch 110/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.3243 - y1_output_loss: 0.5496 - y2_output_loss: 1.7643 - y1_output_root_mean_squared_error: 0.7438 - y2_output_root_mean_squared_error: 1.3308 - val_loss: 3.5860 - val_y1_output_loss: 0.4492 - val_y2_output_loss: 3.1143 - val_y1_output_root_mean_squared_error: 0.6795 - val_y2_output_root_mean_squared_error: 1.7676
# Epoch 111/500
# 614/614 [==============================] - 0s 145us/sample - loss: 3.8850 - y1_output_loss: 0.9535 - y2_output_loss: 2.8984 - y1_output_root_mean_squared_error: 0.9806 - y2_output_root_mean_squared_error: 1.7098 - val_loss: 1.9568 - val_y1_output_loss: 0.3982 - val_y2_output_loss: 1.6415 - val_y1_output_root_mean_squared_error: 0.6367 - val_y2_output_root_mean_squared_error: 1.2456
# Epoch 112/500
# 614/614 [==============================] - 0s 144us/sample - loss: 2.3486 - y1_output_loss: 0.5715 - y2_output_loss: 1.7785 - y1_output_root_mean_squared_error: 0.7573 - y2_output_root_mean_squared_error: 1.3323 - val_loss: 2.2961 - val_y1_output_loss: 0.6015 - val_y2_output_loss: 1.7981 - val_y1_output_root_mean_squared_error: 0.7821 - val_y2_output_root_mean_squared_error: 1.2979
# Epoch 113/500
# 614/614 [==============================] - 0s 147us/sample - loss: 2.0084 - y1_output_loss: 0.4751 - y2_output_loss: 1.5217 - y1_output_root_mean_squared_error: 0.6915 - y2_output_root_mean_squared_error: 1.2370 - val_loss: 1.9383 - val_y1_output_loss: 0.2914 - val_y2_output_loss: 1.7642 - val_y1_output_root_mean_squared_error: 0.5480 - val_y2_output_root_mean_squared_error: 1.2798
# Epoch 114/500
# 614/614 [==============================] - 0s 151us/sample - loss: 3.1742 - y1_output_loss: 0.8983 - y2_output_loss: 2.2645 - y1_output_root_mean_squared_error: 0.9467 - y2_output_root_mean_squared_error: 1.5093 - val_loss: 3.2022 - val_y1_output_loss: 0.8223 - val_y2_output_loss: 2.4303 - val_y1_output_root_mean_squared_error: 0.9212 - val_y2_output_root_mean_squared_error: 1.5341
# Epoch 115/500
# 614/614 [==============================] - 0s 143us/sample - loss: 2.2539 - y1_output_loss: 0.6413 - y2_output_loss: 1.6369 - y1_output_root_mean_squared_error: 0.8025 - y2_output_root_mean_squared_error: 1.2688 - val_loss: 3.1210 - val_y1_output_loss: 0.6124 - val_y2_output_loss: 2.5214 - val_y1_output_root_mean_squared_error: 0.7953 - val_y2_output_root_mean_squared_error: 1.5775
# Epoch 116/500
# 614/614 [==============================] - 0s 144us/sample - loss: 2.2636 - y1_output_loss: 0.5655 - y2_output_loss: 1.6804 - y1_output_root_mean_squared_error: 0.7544 - y2_output_root_mean_squared_error: 1.3017 - val_loss: 2.0883 - val_y1_output_loss: 0.4869 - val_y2_output_loss: 1.6707 - val_y1_output_root_mean_squared_error: 0.7052 - val_y2_output_root_mean_squared_error: 1.2613
# Epoch 117/500
# 614/614 [==============================] - 0s 147us/sample - loss: 2.2793 - y1_output_loss: 0.5940 - y2_output_loss: 1.7196 - y1_output_root_mean_squared_error: 0.7707 - y2_output_root_mean_squared_error: 1.2982 - val_loss: 8.4188 - val_y1_output_loss: 0.9612 - val_y2_output_loss: 7.4243 - val_y1_output_root_mean_squared_error: 0.9822 - val_y2_output_root_mean_squared_error: 2.7302
# Epoch 118/500
# 614/614 [==============================] - 0s 143us/sample - loss: 2.6453 - y1_output_loss: 0.6126 - y2_output_loss: 2.0106 - y1_output_root_mean_squared_error: 0.7847 - y2_output_root_mean_squared_error: 1.4246 - val_loss: 1.9582 - val_y1_output_loss: 0.2821 - val_y2_output_loss: 1.7022 - val_y1_output_root_mean_squared_error: 0.5376 - val_y2_output_root_mean_squared_error: 1.2920
# Epoch 119/500
# 614/614 [==============================] - 0s 138us/sample - loss: 1.7887 - y1_output_loss: 0.4225 - y2_output_loss: 1.3556 - y1_output_root_mean_squared_error: 0.6520 - y2_output_root_mean_squared_error: 1.1677 - val_loss: 2.2329 - val_y1_output_loss: 0.3819 - val_y2_output_loss: 1.8628 - val_y1_output_root_mean_squared_error: 0.6238 - val_y2_output_root_mean_squared_error: 1.3578
# Epoch 120/500
# 614/614 [==============================] - 0s 142us/sample - loss: 1.6904 - y1_output_loss: 0.4123 - y2_output_loss: 1.2775 - y1_output_root_mean_squared_error: 0.6413 - y2_output_root_mean_squared_error: 1.1310 - val_loss: 2.5906 - val_y1_output_loss: 0.5207 - val_y2_output_loss: 2.0722 - val_y1_output_root_mean_squared_error: 0.7340 - val_y2_output_root_mean_squared_error: 1.4324
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.4896 - y1_output_loss: 0.1458 - y2_output_loss: 0.3423 - y1_output_root_mean_squared_error: 0.3828 - y2_output_root_mean_squared_error: 0.5857 - val_loss: 0.8051 - val_y1_output_loss: 0.1712 - val_y2_output_loss: 0.6542 - val_y1_output_root_mean_squared_error: 0.4182 - val_y2_output_root_mean_squared_error: 0.7938
# Epoch 462/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.3475 - y1_output_loss: 0.1064 - y2_output_loss: 0.2394 - y1_output_root_mean_squared_error: 0.3274 - y2_output_root_mean_squared_error: 0.4902 - val_loss: 0.8384 - val_y1_output_loss: 0.1950 - val_y2_output_loss: 0.6458 - val_y1_output_root_mean_squared_error: 0.4468 - val_y2_output_root_mean_squared_error: 0.7992
# Epoch 463/500
# 614/614 [==============================] - 0s 155us/sample - loss: 0.3777 - y1_output_loss: 0.1158 - y2_output_loss: 0.2616 - y1_output_root_mean_squared_error: 0.3378 - y2_output_root_mean_squared_error: 0.5134 - val_loss: 0.8824 - val_y1_output_loss: 0.2750 - val_y2_output_loss: 0.6129 - val_y1_output_root_mean_squared_error: 0.5320 - val_y2_output_root_mean_squared_error: 0.7742
# Epoch 464/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3547 - y1_output_loss: 0.1161 - y2_output_loss: 0.2360 - y1_output_root_mean_squared_error: 0.3419 - y2_output_root_mean_squared_error: 0.4877 - val_loss: 0.7949 - val_y1_output_loss: 0.1591 - val_y2_output_loss: 0.6454 - val_y1_output_root_mean_squared_error: 0.4046 - val_y2_output_root_mean_squared_error: 0.7945
# Epoch 465/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.3326 - y1_output_loss: 0.1081 - y2_output_loss: 0.2217 - y1_output_root_mean_squared_error: 0.3303 - y2_output_root_mean_squared_error: 0.4728 - val_loss: 0.8442 - val_y1_output_loss: 0.1863 - val_y2_output_loss: 0.6541 - val_y1_output_root_mean_squared_error: 0.4359 - val_y2_output_root_mean_squared_error: 0.8088
# Epoch 466/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3539 - y1_output_loss: 0.1243 - y2_output_loss: 0.2270 - y1_output_root_mean_squared_error: 0.3537 - y2_output_root_mean_squared_error: 0.4783 - val_loss: 0.7788 - val_y1_output_loss: 0.1684 - val_y2_output_loss: 0.6365 - val_y1_output_root_mean_squared_error: 0.4160 - val_y2_output_root_mean_squared_error: 0.7783
# Epoch 467/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.4098 - y1_output_loss: 0.1210 - y2_output_loss: 0.2878 - y1_output_root_mean_squared_error: 0.3488 - y2_output_root_mean_squared_error: 0.5368 - val_loss: 1.0337 - val_y1_output_loss: 0.1993 - val_y2_output_loss: 0.8331 - val_y1_output_root_mean_squared_error: 0.4510 - val_y2_output_root_mean_squared_error: 0.9112
# Epoch 468/500
# 614/614 [==============================] - 0s 153us/sample - loss: 0.3704 - y1_output_loss: 0.1448 - y2_output_loss: 0.2232 - y1_output_root_mean_squared_error: 0.3815 - y2_output_root_mean_squared_error: 0.4743 - val_loss: 1.0207 - val_y1_output_loss: 0.2200 - val_y2_output_loss: 0.7975 - val_y1_output_root_mean_squared_error: 0.4736 - val_y2_output_root_mean_squared_error: 0.8924
# Epoch 469/500
# 614/614 [==============================] - 0s 152us/sample - loss: 0.4013 - y1_output_loss: 0.1399 - y2_output_loss: 0.2608 - y1_output_root_mean_squared_error: 0.3739 - y2_output_root_mean_squared_error: 0.5114 - val_loss: 0.8425 - val_y1_output_loss: 0.2185 - val_y2_output_loss: 0.6330 - val_y1_output_root_mean_squared_error: 0.4724 - val_y2_output_root_mean_squared_error: 0.7870
# Epoch 470/500
# 614/614 [==============================] - 0s 159us/sample - loss: 0.4338 - y1_output_loss: 0.1323 - y2_output_loss: 0.3043 - y1_output_root_mean_squared_error: 0.3622 - y2_output_root_mean_squared_error: 0.5501 - val_loss: 1.9555 - val_y1_output_loss: 0.5266 - val_y2_output_loss: 1.3967 - val_y1_output_root_mean_squared_error: 0.7281 - val_y2_output_root_mean_squared_error: 1.1939
# Epoch 471/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.3600 - y1_output_loss: 0.1266 - y2_output_loss: 0.2323 - y1_output_root_mean_squared_error: 0.3574 - y2_output_root_mean_squared_error: 0.4819 - val_loss: 1.0823 - val_y1_output_loss: 0.2453 - val_y2_output_loss: 0.8244 - val_y1_output_root_mean_squared_error: 0.5015 - val_y2_output_root_mean_squared_error: 0.9115
# Epoch 472/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3283 - y1_output_loss: 0.1182 - y2_output_loss: 0.2097 - y1_output_root_mean_squared_error: 0.3452 - y2_output_root_mean_squared_error: 0.4573 - val_loss: 1.6033 - val_y1_output_loss: 0.2167 - val_y2_output_loss: 1.3766 - val_y1_output_root_mean_squared_error: 0.4694 - val_y2_output_root_mean_squared_error: 1.1760
# Epoch 473/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.5500 - y1_output_loss: 0.1640 - y2_output_loss: 0.3940 - y1_output_root_mean_squared_error: 0.4056 - y2_output_root_mean_squared_error: 0.6208 - val_loss: 2.1843 - val_y1_output_loss: 0.1884 - val_y2_output_loss: 2.2345 - val_y1_output_root_mean_squared_error: 0.4369 - val_y2_output_root_mean_squared_error: 1.4119
# Epoch 474/500
# 614/614 [==============================] - 0s 165us/sample - loss: 0.3687 - y1_output_loss: 0.1108 - y2_output_loss: 0.2562 - y1_output_root_mean_squared_error: 0.3342 - y2_output_root_mean_squared_error: 0.5070 - val_loss: 0.9039 - val_y1_output_loss: 0.1680 - val_y2_output_loss: 0.7361 - val_y1_output_root_mean_squared_error: 0.4153 - val_y2_output_root_mean_squared_error: 0.8552
# Epoch 475/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.3048 - y1_output_loss: 0.1080 - y2_output_loss: 0.1946 - y1_output_root_mean_squared_error: 0.3301 - y2_output_root_mean_squared_error: 0.4425 - val_loss: 0.8004 - val_y1_output_loss: 0.1919 - val_y2_output_loss: 0.6596 - val_y1_output_root_mean_squared_error: 0.4406 - val_y2_output_root_mean_squared_error: 0.7786
# Epoch 476/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.8064 - y1_output_loss: 0.2374 - y2_output_loss: 0.5623 - y1_output_root_mean_squared_error: 0.4889 - y2_output_root_mean_squared_error: 0.7533 - val_loss: 0.7455 - val_y1_output_loss: 0.1807 - val_y2_output_loss: 0.5686 - val_y1_output_root_mean_squared_error: 0.4266 - val_y2_output_root_mean_squared_error: 0.7507
# Epoch 477/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3986 - y1_output_loss: 0.1242 - y2_output_loss: 0.2736 - y1_output_root_mean_squared_error: 0.3526 - y2_output_root_mean_squared_error: 0.5237 - val_loss: 0.9128 - val_y1_output_loss: 0.2080 - val_y2_output_loss: 0.6969 - val_y1_output_root_mean_squared_error: 0.4606 - val_y2_output_root_mean_squared_error: 0.8371
# Epoch 478/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.3279 - y1_output_loss: 0.1133 - y2_output_loss: 0.2184 - y1_output_root_mean_squared_error: 0.3358 - y2_output_root_mean_squared_error: 0.4637 - val_loss: 1.8584 - val_y1_output_loss: 0.1943 - val_y2_output_loss: 1.6572 - val_y1_output_root_mean_squared_error: 0.4446 - val_y2_output_root_mean_squared_error: 1.2887
# Epoch 479/500
# 614/614 [==============================] - 0s 153us/sample - loss: 0.3821 - y1_output_loss: 0.1213 - y2_output_loss: 0.2606 - y1_output_root_mean_squared_error: 0.3498 - y2_output_root_mean_squared_error: 0.5097 - val_loss: 0.9700 - val_y1_output_loss: 0.2742 - val_y2_output_loss: 0.7300 - val_y1_output_root_mean_squared_error: 0.5300 - val_y2_output_root_mean_squared_error: 0.8302
# Epoch 480/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.4340 - y1_output_loss: 0.1198 - y2_output_loss: 0.3115 - y1_output_root_mean_squared_error: 0.3463 - y2_output_root_mean_squared_error: 0.5604 - val_loss: 0.7734 - val_y1_output_loss: 0.2001 - val_y2_output_loss: 0.5820 - val_y1_output_root_mean_squared_error: 0.4516 - val_y2_output_root_mean_squared_error: 0.7546
# Epoch 481/500
# 614/614 [==============================] - 0s 165us/sample - loss: 0.3137 - y1_output_loss: 0.1159 - y2_output_loss: 0.1988 - y1_output_root_mean_squared_error: 0.3414 - y2_output_root_mean_squared_error: 0.4440 - val_loss: 1.1983 - val_y1_output_loss: 0.2140 - val_y2_output_loss: 1.0676 - val_y1_output_root_mean_squared_error: 0.4664 - val_y2_output_root_mean_squared_error: 0.9903
# Epoch 482/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.3928 - y1_output_loss: 0.1099 - y2_output_loss: 0.2798 - y1_output_root_mean_squared_error: 0.3323 - y2_output_root_mean_squared_error: 0.5314 - val_loss: 0.8167 - val_y1_output_loss: 0.2304 - val_y2_output_loss: 0.6067 - val_y1_output_root_mean_squared_error: 0.4835 - val_y2_output_root_mean_squared_error: 0.7635
# Epoch 483/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.3684 - y1_output_loss: 0.1305 - y2_output_loss: 0.2431 - y1_output_root_mean_squared_error: 0.3584 - y2_output_root_mean_squared_error: 0.4898 - val_loss: 1.5600 - val_y1_output_loss: 0.3935 - val_y2_output_loss: 1.2321 - val_y1_output_root_mean_squared_error: 0.6289 - val_y2_output_root_mean_squared_error: 1.0791
# Epoch 484/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.4518 - y1_output_loss: 0.1376 - y2_output_loss: 0.3136 - y1_output_root_mean_squared_error: 0.3703 - y2_output_root_mean_squared_error: 0.5609 - val_loss: 0.7708 - val_y1_output_loss: 0.1787 - val_y2_output_loss: 0.6162 - val_y1_output_root_mean_squared_error: 0.4272 - val_y2_output_root_mean_squared_error: 0.7670
# Epoch 485/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.2984 - y1_output_loss: 0.1014 - y2_output_loss: 0.1954 - y1_output_root_mean_squared_error: 0.3197 - y2_output_root_mean_squared_error: 0.4429 - val_loss: 0.7877 - val_y1_output_loss: 0.1916 - val_y2_output_loss: 0.6007 - val_y1_output_root_mean_squared_error: 0.4432 - val_y2_output_root_mean_squared_error: 0.7689
# Epoch 486/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.4220 - y1_output_loss: 0.1387 - y2_output_loss: 0.2800 - y1_output_root_mean_squared_error: 0.3739 - y2_output_root_mean_squared_error: 0.5312 - val_loss: 0.7515 - val_y1_output_loss: 0.1607 - val_y2_output_loss: 0.6158 - val_y1_output_root_mean_squared_error: 0.4050 - val_y2_output_root_mean_squared_error: 0.7665
# Epoch 487/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.3104 - y1_output_loss: 0.1133 - y2_output_loss: 0.1951 - y1_output_root_mean_squared_error: 0.3373 - y2_output_root_mean_squared_error: 0.4434 - val_loss: 1.1745 - val_y1_output_loss: 0.1895 - val_y2_output_loss: 0.9715 - val_y1_output_root_mean_squared_error: 0.4405 - val_y2_output_root_mean_squared_error: 0.9902
# Epoch 488/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.4157 - y1_output_loss: 0.1458 - y2_output_loss: 0.2803 - y1_output_root_mean_squared_error: 0.3676 - y2_output_root_mean_squared_error: 0.5296 - val_loss: 1.1224 - val_y1_output_loss: 0.3249 - val_y2_output_loss: 0.7755 - val_y1_output_root_mean_squared_error: 0.5770 - val_y2_output_root_mean_squared_error: 0.8886
# Epoch 489/500
# 614/614 [==============================] - 0s 160us/sample - loss: 0.3733 - y1_output_loss: 0.1358 - y2_output_loss: 0.2403 - y1_output_root_mean_squared_error: 0.3665 - y2_output_root_mean_squared_error: 0.4889 - val_loss: 1.7037 - val_y1_output_loss: 0.5724 - val_y2_output_loss: 1.0883 - val_y1_output_root_mean_squared_error: 0.7661 - val_y2_output_root_mean_squared_error: 1.0568
# Epoch 490/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.7697 - y1_output_loss: 0.1969 - y2_output_loss: 0.5677 - y1_output_root_mean_squared_error: 0.4454 - y2_output_root_mean_squared_error: 0.7558 - val_loss: 0.9549 - val_y1_output_loss: 0.1907 - val_y2_output_loss: 0.7556 - val_y1_output_root_mean_squared_error: 0.4436 - val_y2_output_root_mean_squared_error: 0.8707
# Epoch 491/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.3606 - y1_output_loss: 0.1223 - y2_output_loss: 0.2370 - y1_output_root_mean_squared_error: 0.3497 - y2_output_root_mean_squared_error: 0.4881 - val_loss: 0.8894 - val_y1_output_loss: 0.1986 - val_y2_output_loss: 0.7140 - val_y1_output_root_mean_squared_error: 0.4528 - val_y2_output_root_mean_squared_error: 0.8273
# Epoch 492/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.3216 - y1_output_loss: 0.1039 - y2_output_loss: 0.2207 - y1_output_root_mean_squared_error: 0.3225 - y2_output_root_mean_squared_error: 0.4664 - val_loss: 1.5673 - val_y1_output_loss: 0.3050 - val_y2_output_loss: 1.2379 - val_y1_output_root_mean_squared_error: 0.5566 - val_y2_output_root_mean_squared_error: 1.1214
# Epoch 493/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.2925 - y1_output_loss: 0.1132 - y2_output_loss: 0.1851 - y1_output_root_mean_squared_error: 0.3360 - y2_output_root_mean_squared_error: 0.4238 - val_loss: 0.8827 - val_y1_output_loss: 0.2465 - val_y2_output_loss: 0.6878 - val_y1_output_root_mean_squared_error: 0.5023 - val_y2_output_root_mean_squared_error: 0.7940
# Epoch 494/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.5801 - y1_output_loss: 0.2016 - y2_output_loss: 0.3750 - y1_output_root_mean_squared_error: 0.4502 - y2_output_root_mean_squared_error: 0.6144 - val_loss: 0.9069 - val_y1_output_loss: 0.2048 - val_y2_output_loss: 0.6961 - val_y1_output_root_mean_squared_error: 0.4570 - val_y2_output_root_mean_squared_error: 0.8355
# Epoch 495/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.3349 - y1_output_loss: 0.1191 - y2_output_loss: 0.2145 - y1_output_root_mean_squared_error: 0.3458 - y2_output_root_mean_squared_error: 0.4640 - val_loss: 0.8721 - val_y1_output_loss: 0.1932 - val_y2_output_loss: 0.6973 - val_y1_output_root_mean_squared_error: 0.4421 - val_y2_output_root_mean_squared_error: 0.8225
# Epoch 496/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.3304 - y1_output_loss: 0.1148 - y2_output_loss: 0.2186 - y1_output_root_mean_squared_error: 0.3359 - y2_output_root_mean_squared_error: 0.4665 - val_loss: 1.1485 - val_y1_output_loss: 0.3151 - val_y2_output_loss: 0.8468 - val_y1_output_root_mean_squared_error: 0.5667 - val_y2_output_root_mean_squared_error: 0.9096
# Epoch 497/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3165 - y1_output_loss: 0.1106 - y2_output_loss: 0.2044 - y1_output_root_mean_squared_error: 0.3321 - y2_output_root_mean_squared_error: 0.4541 - val_loss: 0.8651 - val_y1_output_loss: 0.2125 - val_y2_output_loss: 0.6463 - val_y1_output_root_mean_squared_error: 0.4639 - val_y2_output_root_mean_squared_error: 0.8062
# Epoch 498/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3758 - y1_output_loss: 0.1165 - y2_output_loss: 0.2685 - y1_output_root_mean_squared_error: 0.3424 - y2_output_root_mean_squared_error: 0.5085 - val_loss: 1.8481 - val_y1_output_loss: 0.2727 - val_y2_output_loss: 1.5898 - val_y1_output_root_mean_squared_error: 0.5287 - val_y2_output_root_mean_squared_error: 1.2524
# Epoch 499/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.4220 - y1_output_loss: 0.1152 - y2_output_loss: 0.3052 - y1_output_root_mean_squared_error: 0.3406 - y2_output_root_mean_squared_error: 0.5532 - val_loss: 0.7914 - val_y1_output_loss: 0.1608 - val_y2_output_loss: 0.6337 - val_y1_output_root_mean_squared_error: 0.4061 - val_y2_output_root_mean_squared_error: 0.7915
# Epoch 500/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3549 - y1_output_loss: 0.1121 - y2_output_loss: 0.2402 - y1_output_root_mean_squared_error: 0.3359 - y2_output_root_mean_squared_error: 0.4920 - val_loss: 0.7285 - val_y1_output_loss: 0.1609 - val_y2_output_loss: 0.5709 - val_y1_output_root_mean_squared_error: 0.4070 - val_y2_output_root_mean_squared_error: 0.7503

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 37us/sample - loss: 0.7285 - y1_output_loss: 0.1653 - y2_output_loss: 0.5574 - y1_output_root_mean_squared_error: 0.4070 - y2_output_root_mean_squared_error: 0.7503
# Loss = 0.7285146744220288, Y1_loss = 0.1652528941631317, Y1_mse = 0.4069698750972748, Y2_loss = 0.5573514699935913, Y2_mse = 0.750260055065155

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
